# %%
import pandas as pd
import os
#import seaborn as sns
import matplotlib.pyplot as plt

# %%
model = "cutoff_corr_05" #"cXVAE_inputEmbed"
PATH = f"/trinity/home/skatz/PROJECTS/Multi-view-Deconfounding-VAE/lightning_logs/confounded_square/stability/{model}"

# %%
df = pd.DataFrame()
for folder in os.listdir(f"{PATH}"):   ### XVAE_adversarialTrg
    try: 
        tmp = pd.read_csv(f"{PATH}/{folder}/epoch150/results_performance_removeLatFeatures_pvalueCutoff.csv") ## cufoff_corr: results_performance_removeLatFeatures_pvalueCutoff.csv
        tmp["run"] = folder
        df = pd.concat([df, tmp], axis=0)
    except FileNotFoundError:
        print("Somethign went wrong")
        continue

# %%
df.to_csv("tmp.csv", index=False)

# %%
df.shape
# Out:
# (51, 12)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,5))
ax1.hist(df["ari_confoundedCluster"], bins=20, color="blue")
ax2.hist(df["ari_trueCluster"], bins=20, color="purple")
#ax1.violin(df["ari_confoundedCluster"])
ax1.set_title("ARI - confounded")
ax2.set_title("ARI - true")
# Out:
# Text(0.5, 1.0, 'ARI - true')
