# %%
import os 
import random

# %%
### model = cutoff_corr_05

# %%
''' 
squared confounder 
'''


confounder = "confounded_square"


model = "cutoff_corr_05"
templateFile = "TEMPLATE_vanillaXVAE.py"
seedList = os.listdir(f"/data/scratch/skatz/PROJECTS/multiview_VAE/lightning_logs/{confounder}/stability/{model}")

for outName in seedList:
    print(f"Model name: {outName}")

    #############################################################################
    ########################## change template script  ##########################
    PATH_template = f"{confounder}"
    with open(f"{templateFile}", "r") as f: template=f.read()  
        ## Replace in template file
    template_updated = template.replace("ARG_OUTPUTNAME",  str(outName)) \
                                   .replace("ARG_MODELTYPE", str(model)) \
                                   .replace("ARG_SEED", str(outName.split("_")[1]))
    os.makedirs(f"submit", exist_ok=True)
    with open(f"submit/{outName}.py", "w") as f: f.write(template_updated) ##

    ################################  submit  #################################### 

    # !sbatch ../templateSubmit.sh {PATH_template} {outName}
# Out:
# Model name: run_69276
# Submitted batch job 239135
# Model name: run_90294
# Submitted batch job 239136
# Model name: run_54880
# Submitted batch job 239137
# Model name: run_36808
# Submitted batch job 239138
# Model name: run_23660
# Submitted batch job 239139
# Model name: run_82790
# Submitted batch job 239140
# Model name: run_34168
# Submitted batch job 239141
# Model name: run_87190
# Submitted batch job 239142
# Model name: run_67099
# Submitted batch job 239143
# Model name: run_92940
# Submitted batch job 239144
# Model name: run_87243
# Submitted batch job 239145
# Model name: run_46934
# Submitted batch job 239146
# Model name: run_23747
# Submitted batch job 239147
# Model name: run_67391
# Submitted batch job 239148
# Model name: run_65704
# Submitted batch job 239149
# Model name: run_50887
# Submitted batch job 239150
# Model name: run_90737
# Submitted batch job 239151
# Model name: run_27771
# Submitted batch job 239152
# Model name: run_45867
# Submitted batch job 239153
# Model name: run_849
# Submitted batch job 239154
# Model name: run_99611
# Submitted batch job 239155
# Model name: run_32101
# Submitted batch job 239156
# Model name: run_20299
# Submitted batch job 239157
# Model name: run_21549
# Submitted batch job 239158
# Model name: run_29977
# Submitted batch job 239159
# Model name: run_3595
# Submitted batch job 239160
# Model name: run_89519
# Submitted batch job 239161
# Model name: run_75950
# Submitted batch job 239162
# Model name: run_70398
# Submitted batch job 239163
# Model name: run_6209
# Submitted batch job 239164
# Model name: run_43497
# Submitted batch job 239165
# Model name: run_9142
# Submitted batch job 239166
# Model name: run_9396
# Submitted batch job 239167
# Model name: run_61766
# Submitted batch job 239168
# Model name: run_51839
# Submitted batch job 239169
# Model name: run_54835
# Submitted batch job 239170
# Model name: run_62726
# Submitted batch job 239171
# Model name: run_11008
# Submitted batch job 239172
# Model name: run_70880
# Submitted batch job 239173
# Model name: run_99508
# Submitted batch job 239174
# Model name: run_77577
# Submitted batch job 239175
# Model name: run_35450
# Submitted batch job 239176
# Model name: run_85620
# Submitted batch job 239177
# Model name: run_1936
# Submitted batch job 239178
# Model name: run_1234
# Submitted batch job 239179
# Model name: run_4497
# Submitted batch job 239180
# Model name: run_55311
# Submitted batch job 239181
# Model name: run_3612
# Submitted batch job 239182
# Model name: run_22590
# Submitted batch job 239183
# Model name: run_13245
# Submitted batch job 239184
# Model name: run_64594
# Submitted batch job 239185
