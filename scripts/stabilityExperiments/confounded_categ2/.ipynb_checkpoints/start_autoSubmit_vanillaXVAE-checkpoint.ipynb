# %%
import os 
import random

# %%
### model = cutoff_corr_05

# %%
''' 
Muli confounder 
'''


confounder = "confounded_categ2"


model = "cutoff_corr_05"
templateFile = "TEMPLATE_vanillaXVAE.py"
seedList = os.listdir(f"/data/scratch/skatz/PROJECTS/multiview_VAE/lightning_logs/{confounder}/stability/{model}")

for outName in seedList:
    print(f"Model name: {outName}")

    #############################################################################
    ########################## change template script  ##########################
    PATH_template = f"{confounder}"
    with open(f"{templateFile}", "r") as f: template=f.read()  
        ## Replace in template file
    template_updated = template.replace("ARG_OUTPUTNAME",  str(outName)) \
                                   .replace("ARG_MODELTYPE", str(model)) \
                                   .replace("ARG_SEED", str(outName.split("_")[1]))
    os.makedirs(f"submit", exist_ok=True)
    with open(f"submit/{outName}.py", "w") as f: f.write(template_updated) ##

    ################################  submit  #################################### 

    # !sbatch ../templateSubmit.sh {PATH_template} {outName}
# Out:
# Model name: run_76159
# Submitted batch job 238859
# Model name: run_21381
# Submitted batch job 238860
# Model name: run_38630
# Submitted batch job 238861
# Model name: run_84412
# Submitted batch job 238862
# Model name: run_54716
# Submitted batch job 238863
# Model name: run_43722
# Submitted batch job 238864
# Model name: run_26376
# Submitted batch job 238865
# Model name: run_4723
# Submitted batch job 238866
# Model name: run_74742
# Submitted batch job 238867
# Model name: run_79974
# Submitted batch job 238868
# Model name: run_53038
# Submitted batch job 238869
# Model name: run_82263
# Submitted batch job 238870
# Model name: run_4481
# Submitted batch job 238871
# Model name: run_27903
# Submitted batch job 238872
# Model name: run_75911
# Submitted batch job 238873
# Model name: run_11652
# Submitted batch job 238874
# Model name: run_77538
# Submitted batch job 238875
# Model name: run_82908
# Submitted batch job 238876
# Model name: run_52093
# Submitted batch job 238877
# Model name: run_31021
# Submitted batch job 238878
# Model name: run_64151
# Submitted batch job 238879
# Model name: run_82135
# Submitted batch job 238880
# Model name: run_63979
# Submitted batch job 238881
# Model name: run_29386
# Submitted batch job 238882
# Model name: run_19102
# Submitted batch job 238883
# Model name: run_22174
# Submitted batch job 238884
# Model name: run_90939
# Submitted batch job 238885
# Model name: run_90501
# Submitted batch job 238886
# Model name: run_80312
# Submitted batch job 238887
# Model name: run_70665
# Submitted batch job 238888
# Model name: run_82625
# Submitted batch job 238889
# Model name: run_52366
# Submitted batch job 238890
# Model name: run_18321
# Submitted batch job 238891
# Model name: run_72836
# Submitted batch job 238892
# Model name: run_76973
# Submitted batch job 238893
# Model name: run_69274
# Submitted batch job 238894
# Model name: run_67426
# Submitted batch job 238895
# Model name: run_97907
# Submitted batch job 238896
# Model name: run_79554
# Submitted batch job 238897
# Model name: run_45927
# Submitted batch job 238898
# Model name: run_68711
# Submitted batch job 238899
# Model name: run_41821
# Submitted batch job 238900
# Model name: run_88257
# Submitted batch job 238901
# Model name: run_30568
# Submitted batch job 238902
# Model name: run_98497
# Submitted batch job 238903
# Model name: run_25712
# Submitted batch job 238904
# Model name: run_22448
# Submitted batch job 238905
# Model name: run_8662
# Submitted batch job 238906
# Model name: run_15824
# Submitted batch job 238907
# Model name: run_89552
# Submitted batch job 238908
